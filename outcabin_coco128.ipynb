# %% [markdown]
# <a href="https://colab.research.google.com/github/AnxiousCodeGeek/AnxiousCodeGeek/blob/main/outcabin_coco128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-338-gff063284 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)

# %%
cd /content/yolov5
# Out:
# /content/yolov5

# %%
import time
from google.colab import output

# JavaScript to simulate mouse activity
js_code = """
function ClickConnect(){
  console.log("Clicked on connect button to prevent timeout");
  document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect, 60000)
"""

output.eval_js(js_code)
# Out:
# 18

# %%
import zipfile

with zipfile.ZipFile('/content/yolov5/coco128.zip', 'r') as zip_ref:
    zip_ref.extractall('coco128')

# %%
# !python train.py --batch 8 --weights '' --data /content/yolov5/data/coco128.yaml --cfg /content/yolov5/models/yolov5s.yaml --img 640 --epochs 300
# Out:
# 2024-07-09 13:01:14.664330: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 13:01:14.664388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 13:01:14.741658: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --batch 8 --weights /content/yolov5/runs/train/exp/weights/best.pt --data /content/yolov5/data/coco128.yaml --cfg /content/yolov5/models/yolov5s.yaml --img 640 --epochs 300
# Out:
# 2024-07-09 14:32:18.299291: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 14:32:18.299350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 14:32:18.300844: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
